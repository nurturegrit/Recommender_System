# %% [markdown]
# ## Scraping News from New York Times API

# %%
import requests

# %%
# Today's top stories

category = "arts"
api_key = "MKwTYxRt5pkmkwtBqxpO2qxkAKQkGCgO"
base_url = f"https://api.nytimes.com/svc/topstories/v2/{category}.json?api-key={api_key}"

# %%
categories = [
    "arts", "automobiles", "books/review", "business", "fashion", "food", "health",
    "home", "insider", "magazine", "movies", "nyregion", "obituaries", "opinion",
    "politics", "realestate", "science", "sports", "sundayreview", "technology",
    "theater", "t-magazine", "travel", "upshot", "us", "world"
]

# %%
response = requests.get(base_url)

# %%
response.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'section': 'Arts',
#  'last_updated': '2024-12-25T08:35:05-05:00',
#  'num_results': 38,
#  'results': [{'section': 'movies',
#    'subsection': '',
#    'title': 'The First ‘Peter Pan’ Blockbuster Turns 100 but Hasn’t Grown Up',
#    'abstract': 'The silent film debuted in 1924 to much fanfare but was later lost. Eventually rediscovered and restored, it has gone on to charm new generations of fans.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/peter-pan-movie-100th-anniversary.html',
#    'uri': 'nyt://article/68ad0867-ac7c-590d-890a-f87d139c0b98',
#    'byline': 'By Derrick Bryson Taylor',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T05:00:24-05:00',
#    'created_date': '2024-12-25T05:00:24-05:00',
#    'published_date': '2024-12-25T05:00:24-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies',
#     'Nineteen Hundred Twenties',
#     'Peter Pan (Movie)',
#     'Peter Pan (Play)'],
#    'org_facet': [],
#    'per_facet': ['Barrie, James Matthew', 'Disney, Walt', 'Betty Bronson'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/peter-pan-mcwb/peter-pan-mcwb-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Betty Bronson played the title role in the 1924 silent film “Peter Pan,” a blockbuster of its era that is considered a pioneer for movie-related merchandise.',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/peter-pan-mcwb/peter-pan-mcwb-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Betty Bronson played the title role in the 1924 silent film “Peter Pan,” a blockbuster of its era that is considered a pioneer for movie-related merchandise.',
#      'copyright': ''},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/peter-pan-mcwb/peter-pan-mcwb-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Betty Bronson played the title role in the 1924 silent film “Peter Pan,” a blockbuster of its era that is considered a pioneer for movie-related merchandise.',
#      'copyright': ''}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': 'How Airlines Pick the Movies on Your Flights',
#    'abstract': 'Sure, everyone likes “Barbie.” But who knew that “Cats” would be a hit at 35,000 feet?',
#    'url': 'https://www.nytimes.com/2024/12/22/movies/movies-airlines-flights.html',
#    'uri': 'nyt://article/5cd9984a-22f0-5771-a826-56e607c91ff4',
#    'byline': 'By Matt Stevens',
#    'item_type': 'Article',
#    'updated_date': '2024-12-23T10:29:58-05:00',
#    'created_date': '2024-12-22T05:00:13-05:00',
#    'published_date': '2024-12-22T05:00:13-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Airlines and Airplanes',
#     'Movies',
#     'Television',
#     'Travel and Vacations'],
#    'org_facet': ['American Airlines',
#     'Delta Air Lines Inc',
#     'United Airlines',
#     'Southwest Airlines Company'],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/29/multimedia/29airplane-movies-mgbw/29airplane-movies-mgbw-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“Cats” may have flopped at the box office but at one point it was the most popular movie on Southwest Airlines.',
#      'copyright': 'Universal Pictures'},
#     {'url': 'https://static01.nyt.com/images/2024/12/29/multimedia/29airplane-movies-mgbw/29airplane-movies-mgbw-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“Cats” may have flopped at the box office but at one point it was the most popular movie on Southwest Airlines.',
#      'copyright': 'Universal Pictures'},
#     {'url': 'https://static01.nyt.com/images/2024/12/29/multimedia/29airplane-movies-mgbw/29airplane-movies-mgbw-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“Cats” may have flopped at the box office but at one point it was the most popular movie on Southwest Airlines.',
#      'copyright': 'Universal Pictures'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': 'What’s the Secret to Choosing a Good Airplane Movie?',
#    'abstract': 'You’re about to get on a long flight home, and the options seem overwhelming. Here’s the strategy our critic recommends.',
#    'url': 'https://www.nytimes.com/2024/12/22/movies/airplane-movies-in-flight-entertainment.html',
#    'uri': 'nyt://article/e4ddffdc-f423-5d3a-8634-b6170d702461',
#    'byline': 'By Alissa Wilkinson',
#    'item_type': 'Article',
#    'updated_date': '2024-12-23T10:34:33-05:00',
#    'created_date': '2024-12-22T05:01:07-05:00',
#    'published_date': '2024-12-22T05:01:07-05:00',
#    'material_type_facet': '',
#    'kicker': 'Ask A&L',
#    'des_facet': ['Movies',
#     'Airlines and Airplanes',
#     'Travel and Vacations',
#     'Content Type: Service'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/22/arts/22ask-airplanemovies/22ask-airplanemovies-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Melanie Lambrick'},
#     {'url': 'https://static01.nyt.com/images/2024/12/22/arts/22ask-airplanemovies/22ask-airplanemovies-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Melanie Lambrick'},
#     {'url': 'https://static01.nyt.com/images/2024/12/22/arts/22ask-airplanemovies/22ask-airplanemovies-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Melanie Lambrick'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'design',
#    'title': 'The Mysterious Donor Who Fled Communism and Left Millions to the Art World',
#    'abstract': 'Aso O. Tavitian grew up poor — but at age 64 he began an ‘‘explosion of buying.” Under the radar, he amassed old masters, leaving 331 to the Clark. How did he do it?',
#    'url': 'https://www.nytimes.com/2024/12/24/arts/design/tavitian-collector-old-masters-auction-art-clark.html',
#    'uri': 'nyt://article/5771bf6d-8cdd-509f-ae31-849d4530d54d',
#    'byline': 'By Ted Loos',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T13:44:33-05:00',
#    'created_date': '2024-12-24T05:01:55-05:00',
#    'published_date': '2024-12-24T05:01:55-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Art',
#     'Collectors and Collections',
#     'Auctions',
#     'Antiques',
#     'Philanthropy'],
#    'org_facet': ['Clark, Sterling and Francine, Art Institute', "Sotheby's"],
#    'per_facet': ['Tavitian, Aso O', 'Watteau, Jean-Antoine'],
#    'geo_facet': ['Berkshires (Mass)', 'New York City'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/arts/00TAVITIAN-OLD-MASTER-GRID/00TAVITIAN-OLD-MASTER-GRID-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 1639,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Renaissance masterworks from the collection of Aso O. Tavitian, including some, among hundreds, that were gifts to the Clark Art Institute and others to be auctioned at Sotheby’s New York in February.',
#      'copyright': "via Clark Art Institute, Williamstown, Massachusetts; via Sotheby's; Michael Bodycomb; via The Metropolitan Museum of Art, New York"},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/arts/00TAVITIAN-OLD-MASTER-GRID/00TAVITIAN-OLD-MASTER-GRID-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Renaissance masterworks from the collection of Aso O. Tavitian, including some, among hundreds, that were gifts to the Clark Art Institute and others to be auctioned at Sotheby’s New York in February.',
#      'copyright': "via Clark Art Institute, Williamstown, Massachusetts; via Sotheby's; Michael Bodycomb; via The Metropolitan Museum of Art, New York"},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/arts/00TAVITIAN-OLD-MASTER-GRID/00TAVITIAN-OLD-MASTER-GRID-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Renaissance masterworks from the collection of Aso O. Tavitian, including some, among hundreds, that were gifts to the Clark Art Institute and others to be auctioned at Sotheby’s New York in February.',
#      'copyright': "via Clark Art Institute, Williamstown, Massachusetts; via Sotheby's; Michael Bodycomb; via The Metropolitan Museum of Art, New York"}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'music',
#    'title': 'How ‘Rudolph the Red-Nosed Reindeer’ (and Its Writer) Went Down in History',
#    'abstract': 'Johnny Marks wrote the beloved holiday song, as well as “Rockin’ Around the Christmas Tree.” But he felt pigeonholed by the success of “Rudolph.”',
#    'url': 'https://www.nytimes.com/2024/12/23/arts/music/johnny-marks-rudolph-the-red-nosed-reindeer.html',
#    'uri': 'nyt://article/b02020ae-a836-5828-8aa8-f2bed178bafd',
#    'byline': 'By Danny Freedman',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T09:56:55-05:00',
#    'created_date': '2024-12-23T05:00:23-05:00',
#    'published_date': '2024-12-23T05:00:23-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Music',
#     'Christmas',
#     'Content Type: Personal Profile',
#     'Rudolph the Red-Nosed Reindeer (Song)'],
#    'org_facet': [],
#    'per_facet': ['Marks, Johnny D (1909-85)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23mr-christmas1-bjvg/23mr-christmas1-bjvg-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 1599,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The songwriter Johnny Marks at the piano in 1956. He wrote so many successful holiday songs, he became known as “Mr. Christmas.”',
#      'copyright': 'Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23mr-christmas1-bjvg/23mr-christmas1-bjvg-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The songwriter Johnny Marks at the piano in 1956. He wrote so many successful holiday songs, he became known as “Mr. Christmas.”',
#      'copyright': 'Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23mr-christmas1-bjvg/23mr-christmas1-bjvg-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The songwriter Johnny Marks at the piano in 1956. He wrote so many successful holiday songs, he became known as “Mr. Christmas.”',
#      'copyright': 'Associated Press'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'music',
#    'title': 'Lin-Manuel Miranda on ‘Mufasa’ and the Secret to a Disney Hit',
#    'abstract': 'The “Hamilton” creator, who crafted the soundtrack for the new prequel to “The Lion King,” reflects on writing songs that have a universal appeal.',
#    'url': 'https://www.nytimes.com/2024/12/22/arts/music/lin-manuel-miranda-mufasa.html',
#    'uri': 'nyt://article/da402631-25ee-50ab-89f3-c3feb8f70736',
#    'byline': 'By Sarah Bahr',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T09:21:41-05:00',
#    'created_date': '2024-12-22T05:01:02-05:00',
#    'published_date': '2024-12-22T05:01:02-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Mufasa: The Lion King (Movie)',
#     'Music',
#     'Animated Films',
#     'Moana (Movie)',
#     'Content Type: Personal Profile',
#     'Moana 2 (Movie)'],
#    'org_facet': ['Walt Disney Company'],
#    'per_facet': ['Miranda, Lin-Manuel'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/22lin-manuel-qa-hljv/22lin-manuel-qa-hljv-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1136,
#      'width': 1704,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lin-Manuel Miranda wrote seven songs for “Mufasa: The Lion King,” directed by Barry Jenkins.',
#      'copyright': 'Nina Westervelt for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/22lin-manuel-qa-hljv/22lin-manuel-qa-hljv-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lin-Manuel Miranda wrote seven songs for “Mufasa: The Lion King,” directed by Barry Jenkins.',
#      'copyright': 'Nina Westervelt for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/22lin-manuel-qa-hljv/22lin-manuel-qa-hljv-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lin-Manuel Miranda wrote seven songs for “Mufasa: The Lion King,” directed by Barry Jenkins.',
#      'copyright': 'Nina Westervelt for The New York Times'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'music',
#    'title': 'Best Classical Music Albums of 2024',
#    'abstract': 'Listen to selections from recordings of a new John Adams opera, Chopin études by Yunchan Lim, Brahms works by Igor Levit and more.',
#    'url': 'https://www.nytimes.com/2024/12/22/arts/music/best-classical-music-albums-recordings-2024.html',
#    'uri': 'nyt://article/c4581f3a-b461-5983-bca0-d59979a02ff9',
#    'byline': '',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T09:01:01-05:00',
#    'created_date': '2024-12-22T05:00:54-05:00',
#    'published_date': '2024-12-22T05:00:54-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Classical Music', 'Opera'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/22/arts/22best-classical-recordings/22best-classical-recordings-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The year’s best recordings include releases by, from left, Kirill Gerstein, the Danish String Quartet and María Dueñas.',
#      'copyright': 'Amy Lombard for The New York Times, James Estrin/The New York Times, Hannah Beier for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/22/arts/22best-classical-recordings/22best-classical-recordings-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The year’s best recordings include releases by, from left, Kirill Gerstein, the Danish String Quartet and María Dueñas.',
#      'copyright': 'Amy Lombard for The New York Times, James Estrin/The New York Times, Hannah Beier for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/22/arts/22best-classical-recordings/22best-classical-recordings-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The year’s best recordings include releases by, from left, Kirill Gerstein, the Danish String Quartet and María Dueñas.',
#      'copyright': 'Amy Lombard for The New York Times, James Estrin/The New York Times, Hannah Beier for The New York Times'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': 'Meet the Director Who Reinvented the Act of Seeing',
#    'abstract': 'In “Nickel Boys,” RaMell Ross uses what he calls “sentient perspective” to convey the characters’ view of their world. Critics say the result is stunning.',
#    'url': 'https://www.nytimes.com/2024/12/20/movies/ramell-ross-nickel-boys.html',
#    'uri': 'nyt://article/402c5a9c-8082-59bd-8fcf-d00511956061',
#    'byline': 'By Salamishah Tillet',
#    'item_type': 'Article',
#    'updated_date': '2024-12-22T14:41:17-05:00',
#    'created_date': '2024-12-20T05:01:50-05:00',
#    'published_date': '2024-12-20T05:01:50-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Content Type: Personal Profile',
#     'Movies',
#     'Nickel Boys (Movie)',
#     'Black People',
#     'Hale County This Morning, This Evening (Movie)',
#     'Documentary Films and Programs'],
#    'org_facet': [],
#    'per_facet': ['Ross, RaMell (1982- )', 'Ellis-Taylor, Aunjanue'],
#    'geo_facet': ['Alabama'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2025/01/05/multimedia/ramell-ross-01-fghw/ramell-ross-01-fghw-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1358,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'RaMell Ross in Central Park. He tried to imagine the “Nickel Boys” characters’ world the way they would envision it. He then “challenged myself to see better for them.”',
#      'copyright': 'Andre D. Wagner for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2025/01/05/multimedia/ramell-ross-01-fghw/ramell-ross-01-fghw-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'RaMell Ross in Central Park. He tried to imagine the “Nickel Boys” characters’ world the way they would envision it. He then “challenged myself to see better for them.”',
#      'copyright': 'Andre D. Wagner for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2025/01/05/multimedia/ramell-ross-01-fghw/ramell-ross-01-fghw-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'RaMell Ross in Central Park. He tried to imagine the “Nickel Boys” characters’ world the way they would envision it. He then “challenged myself to see better for them.”',
#      'copyright': 'Andre D. Wagner for The New York Times'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': '',
#    'title': 'Artists We Lost in 2024, in Their Words',
#    'abstract': 'Shelley Duvall, Quincy Jones, Faith Ringgold and Paul Auster are some of the greats who died this year.',
#    'url': 'https://www.nytimes.com/2024/12/20/arts/artists-we-lost-in-2024-in-their-words.html',
#    'uri': 'nyt://article/af792a56-3732-52d2-98b4-947333beed57',
#    'byline': 'By Gabe Cohn',
#    'item_type': 'Article',
#    'updated_date': '2024-12-20T11:03:22-05:00',
#    'created_date': '2024-12-20T05:01:46-05:00',
#    'published_date': '2024-12-20T05:01:46-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Culture (Arts)',
#     'Two Thousand Twenty Four',
#     'Deaths (Obituaries)',
#     'Art',
#     'Actors and Actresses',
#     'Writing and Writers',
#     'Dancing',
#     'Music'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20artists-we-lost-2024-bwgh/20artists-we-lost-2024-bwgh-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1504,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Shelley Duvall',
#      'copyright': 'Stanley Bielecki Movie Collection/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20artists-we-lost-2024-bwgh/20artists-we-lost-2024-bwgh-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Shelley Duvall',
#      'copyright': 'Stanley Bielecki Movie Collection/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20artists-we-lost-2024-bwgh/20artists-we-lost-2024-bwgh-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Shelley Duvall',
#      'copyright': 'Stanley Bielecki Movie Collection/Getty Images'}],
#    'short_url': ''},
#   {'section': 'theater',
#    'subsection': '',
#    'title': 'Review: In a Stripped-Down ‘Gypsy,’ Audra’s Gonna Show It to Ya',
#    'abstract': 'Hold your hats and hallelujah, our leading musical tragedienne offers an ultra-dramatic Rose in George C. Wolfe’s Broadway revival.',
#    'url': 'https://www.nytimes.com/2024/12/20/theater/gypsy-review-audra-mcdonald.html',
#    'uri': 'nyt://article/8d8f8625-682f-5aee-86d0-34becdb3ff8e',
#    'byline': 'By Jesse Green',
#    'item_type': 'Article',
#    'updated_date': '2024-12-20T00:01:06-05:00',
#    'created_date': '2024-12-20T00:01:06-05:00',
#    'published_date': '2024-12-20T00:01:06-05:00',
#    'material_type_facet': '',
#    'kicker': 'Critic’s Pick',
#    'des_facet': ['Theater', 'Theater (Broadway)', 'Gypsy (Play)'],
#    'org_facet': ['Majestic Theater (Manhattan, NY)'],
#    'per_facet': ['Styne, Jule',
#     'Sondheim, Stephen',
#     'Laurents, Arthur',
#     'Wolfe, George C',
#     'McDonald, Audra',
#     'Burstein, Danny'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/19GYPSY-1-wtgz/19GYPSY-1-wtgz-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1586,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Audra McDonald makes a meal of Rose’s ambition and a dessert of her guile in the latest Broadway revival of “Gypsy.”',
#      'copyright': 'Sara Krulwich/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/19GYPSY-1-wtgz/19GYPSY-1-wtgz-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Audra McDonald makes a meal of Rose’s ambition and a dessert of her guile in the latest Broadway revival of “Gypsy.”',
#      'copyright': 'Sara Krulwich/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/19GYPSY-1-wtgz/19GYPSY-1-wtgz-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Audra McDonald makes a meal of Rose’s ambition and a dessert of her guile in the latest Broadway revival of “Gypsy.”',
#      'copyright': 'Sara Krulwich/The New York Times'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'music',
#    'title': 'Why Composers of Any (or No) Faith Are Drawn to Sacred Music',
#    'abstract': 'Many Christmas standards were not written by Christians. David Lang explains the appeal for him, a Jewish composer of a modern holiday classic.',
#    'url': 'https://www.nytimes.com/2024/12/20/arts/music/david-lang-little-match-girl-passion-christmas.html',
#    'uri': 'nyt://article/e064800d-bfc1-5009-8f1e-f8c6cf45f7d5',
#    'byline': 'By David Lang',
#    'item_type': 'Article',
#    'updated_date': '2024-12-21T00:41:56-05:00',
#    'created_date': '2024-12-20T05:01:57-05:00',
#    'published_date': '2024-12-20T05:01:57-05:00',
#    'material_type_facet': '',
#    'kicker': 'Essay',
#    'des_facet': ['Christmas',
#     'Classical Music',
#     'Religion and Belief',
#     'Music',
#     'Content Type: Personal Profile',
#     'The Little Match Girl Passion (Musical Work)',
#     'Poor Hymnal (Musical Work)'],
#    'org_facet': [],
#    'per_facet': ['Lang, David'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/21/arts/sacred-music-illo/sacred-music-illo-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 2033,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Antoine Coss&eacute;'},
#     {'url': 'https://static01.nyt.com/images/2024/12/21/arts/sacred-music-illo/sacred-music-illo-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Antoine Coss&eacute;'},
#     {'url': 'https://static01.nyt.com/images/2024/12/21/arts/sacred-music-illo/sacred-music-illo-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Antoine Coss&eacute;'}],
#    'short_url': ''},
#   {'section': 'theater',
#    'subsection': '',
#    'title': '21 Movies, Books and Albums With a Theater Focus to Consume During the Holidays',
#    'abstract': 'Make it through the holidays with these movies, books and music from the past year that are adapted from stage productions or evoke a theatrical spirit.',
#    'url': 'https://www.nytimes.com/2024/12/20/theater/theater-adaptations-movies-books-music.html',
#    'uri': 'nyt://article/5efa1efe-860a-53c2-b58f-0ee701ccc5f4',
#    'byline': 'By Nicole Herrington and Rachel Sherman',
#    'item_type': 'Article',
#    'updated_date': '2024-12-21T07:33:26-05:00',
#    'created_date': '2024-12-20T13:32:23-05:00',
#    'published_date': '2024-12-20T13:32:23-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Theater',
#     'Theater (Broadway)',
#     'Theater (Off Broadway)',
#     'Books and Literature',
#     'Culture (Arts)',
#     'Movies',
#     'Content Type: Service',
#     'Music'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20theater-at-home-1-wbpz/20theater-at-home-1-wbpz-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Danielle Deadwyler as Berniece and Ray Fisher as Lymon in “The Piano Lesson,” which is streaming on Netflix.',
#      'copyright': 'David Lee/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20theater-at-home-1-wbpz/20theater-at-home-1-wbpz-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Danielle Deadwyler as Berniece and Ray Fisher as Lymon in “The Piano Lesson,” which is streaming on Netflix.',
#      'copyright': 'David Lee/Netflix'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20theater-at-home-1-wbpz/20theater-at-home-1-wbpz-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Danielle Deadwyler as Berniece and Ray Fisher as Lymon in “The Piano Lesson,” which is streaming on Netflix.',
#      'copyright': 'David Lee/Netflix'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Elton John: Never Too Late’ Burnishes a Career (but Charmingly)',
#    'abstract': 'The star is in positive, future-looking mode in this Disney+ documentary, directed by his husband, David Furnish, and R.J. Cutler.',
#    'url': 'https://www.nytimes.com/2024/12/20/movies/elton-john-doc-never-too-late.html',
#    'uri': 'nyt://article/54d20a29-2b23-5ba0-bfbb-14b924349d65',
#    'byline': 'By Alissa Wilkinson',
#    'item_type': 'Article',
#    'updated_date': '2024-12-22T22:22:12-05:00',
#    'created_date': '2024-12-20T05:02:15-05:00',
#    'published_date': '2024-12-20T05:02:15-05:00',
#    'material_type_facet': '',
#    'kicker': 'Documentary Lens',
#    'des_facet': ['Pop and Rock Music',
#     'Documentary Films and Programs',
#     'Elton John: Never Too Late (Movie)'],
#    'org_facet': ['Disney Plus'],
#    'per_facet': ['Cutler, R J', 'Furnish, David J', 'John, Elton'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/20doc-col-gwjf/20doc-col-gwjf-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1337,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Elton John in 1976, in a scene from “Never Too Late.”',
#      'copyright': 'Ron Pownall, via Disney'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/20doc-col-gwjf/20doc-col-gwjf-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Elton John in 1976, in a scene from “Never Too Late.”',
#      'copyright': 'Ron Pownall, via Disney'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/20doc-col-gwjf/20doc-col-gwjf-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Elton John in 1976, in a scene from “Never Too Late.”',
#      'copyright': 'Ron Pownall, via Disney'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': '',
#    'title': 'New Year’s Eve in New York: What to Do, See and Eat',
#    'abstract': 'Whether you brave Times Square, pop into a drag show or snuggle up in a heated igloo, we have you covered for this year’s countdown.',
#    'url': 'https://www.nytimes.com/2024/12/20/arts/new-years-eve-nyc.html',
#    'uri': 'nyt://article/bb7e8981-b8a5-528c-8c85-08fd41011774',
#    'byline': 'By Erik Piepenburg',
#    'item_type': 'Article',
#    'updated_date': '2024-12-20T05:01:30-05:00',
#    'created_date': '2024-12-20T05:01:30-05:00',
#    'published_date': '2024-12-20T05:01:30-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': [],
#    'org_facet': ['Beacon Theater',
#     'Ailey, Alvin, American Dance Theater',
#     'Brooklyn Bowl',
#     'Cafe Carlyle (Manhattan, NY)',
#     'Cathedral Church of St John the Divine (Manhattan, NY)',
#     'Comedy Cellar',
#     'UBS Arena (Elmont, NY)',
#     'Terminal 5 (Manhattan, NY, Music Venue)'],
#    'per_facet': [],
#    'geo_facet': ['New York City'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/arts/20nye-events-roundup-top/20nye-events-roundup-top-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'For maximum chaos, there’s always the ball drop at Times Square.',
#      'copyright': 'Gary Hershorn/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/arts/20nye-events-roundup-top/20nye-events-roundup-top-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'For maximum chaos, there’s always the ball drop at Times Square.',
#      'copyright': 'Gary Hershorn/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/arts/20nye-events-roundup-top/20nye-events-roundup-top-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'For maximum chaos, there’s always the ball drop at Times Square.',
#      'copyright': 'Gary Hershorn/Getty Images'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Babygirl’ Review: Nicole Kidman Takes Control',
#    'abstract': 'Nicole Kidman bares body and some soul in a story about a married woman who enters a dominant-submissive affair with a younger man.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/babygirl-review.html',
#    'uri': 'nyt://article/471940c5-2c02-5134-922e-5ad006a8fe76',
#    'byline': 'By Manohla Dargis',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T13:22:47-05:00',
#    'created_date': '2024-12-25T10:00:15-05:00',
#    'published_date': '2024-12-25T10:00:15-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'Babygirl (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Kidman, Nicole',
#     'Dickinson, Harris (1996- )',
#     'Reijn, Halina'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25babygirl-review-wfkl/25babygirl-review-wfkl-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1366,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Nicole Kidman and Harris Dickinson in “Babygirl.”',
#      'copyright': 'Niko Tavernise/A24'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25babygirl-review-wfkl/25babygirl-review-wfkl-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Nicole Kidman and Harris Dickinson in “Babygirl.”',
#      'copyright': 'Niko Tavernise/A24'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25babygirl-review-wfkl/25babygirl-review-wfkl-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Nicole Kidman and Harris Dickinson in “Babygirl.”',
#      'copyright': 'Niko Tavernise/A24'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': 'How Nicholas Hoult Navigates a Transylvanian Village in ‘Nosferatu’',
#    'abstract': 'The director Robert Eggers narrates a one-shot sequence from his film.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/nosferatu-clip.html',
#    'uri': 'nyt://article/9d61ca79-7574-573f-86c0-03eedf27840c',
#    'byline': 'By Mekado Murphy',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T07:00:04-05:00',
#    'created_date': '2024-12-25T07:00:04-05:00',
#    'published_date': '2024-12-25T07:00:04-05:00',
#    'material_type_facet': '',
#    'kicker': 'Anatomy of a Scene',
#    'des_facet': ['Movies'],
#    'org_facet': [],
#    'per_facet': ['Hoult, Nicholas', 'Eggers, Robert (Filmmaker)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/nosferatu-anatomy-mzhc/nosferatu-anatomy-mzhc-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1152,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Aidan Monaghan/Focus Features'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/nosferatu-anatomy-mzhc/nosferatu-anatomy-mzhc-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Aidan Monaghan/Focus Features'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/nosferatu-anatomy-mzhc/nosferatu-anatomy-mzhc-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Aidan Monaghan/Focus Features'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘A Complete Unknown’ Review: Timothée Chalamet Goes Electric',
#    'abstract': 'The actor stars as a young Bob Dylan, who woos folk followers only to betray them later at the 1965 Newport Folk Festival.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/a-complete-unknown-review.html',
#    'uri': 'nyt://article/02c4888a-9255-503f-bcff-4f7a568651a8',
#    'byline': 'By Manohla Dargis',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T12:44:23-05:00',
#    'created_date': '2024-12-25T05:09:52-05:00',
#    'published_date': '2024-12-25T05:09:52-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Movies', 'A Complete Unknown (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Barbaro, Monica (1990- )',
#     'Chalamet, Timothee (1995- )',
#     'Dylan, Bob',
#     'Fanning, Elle'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25completeunknown-review-wcqm/25completeunknown-review-wcqm-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Timothée Chalamet as Bob Dylan in “A Complete Unknown.”',
#      'copyright': 'Macall Polay/Searchlight Pictures'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25completeunknown-review-wcqm/25completeunknown-review-wcqm-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Timothée Chalamet as Bob Dylan in “A Complete Unknown.”',
#      'copyright': 'Macall Polay/Searchlight Pictures'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25completeunknown-review-wcqm/25completeunknown-review-wcqm-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Timothée Chalamet as Bob Dylan in “A Complete Unknown.”',
#      'copyright': 'Macall Polay/Searchlight Pictures'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': 'In ‘Babygirl’ Nicole Kidman Wants Him. But What Does Harris Dickinson Want?',
#    'abstract': 'The rising British actor has a sexy star turn opposite in the new film, but he is of two minds when it comes to his career: “Acting is neurotic.”',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/harris-dickinson-nicole-kidman-babygirl.html',
#    'uri': 'nyt://article/19994afc-57e0-5a15-814d-583cd15347bd',
#    'byline': 'By Kyle Buchanan and Chantal Anderson',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T05:01:40-05:00',
#    'created_date': '2024-12-25T05:01:40-05:00',
#    'published_date': '2024-12-25T05:01:40-05:00',
#    'material_type_facet': '',
#    'kicker': 'The Projectionist',
#    'des_facet': ['Movies',
#     'Babygirl (Movie)',
#     'Content Type: Personal Profile'],
#    'org_facet': [],
#    'per_facet': ['Dickinson, Harris (1996- )'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/HARRIS-DICKINSON-PROMO-kqtf/HARRIS-DICKINSON-PROMO-kqtf-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1536,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Chantal Anderson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/HARRIS-DICKINSON-PROMO-kqtf/HARRIS-DICKINSON-PROMO-kqtf-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Chantal Anderson for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/HARRIS-DICKINSON-PROMO-kqtf/HARRIS-DICKINSON-PROMO-kqtf-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Chantal Anderson for The New York Times'}],
#    'short_url': ''},
#   {'section': 'travel',
#    'subsection': '',
#    'title': 'The Writer of the Netflix Hit ‘Carry-On’ Talks About the ‘Trolley Problem’ and the T. S.A.',
#    'abstract': 'T.J. Fixman on what makes an exciting Christmas thriller, his own interactions with airport security and what you shouldn’t leave in your luggage.',
#    'url': 'https://www.nytimes.com/2024/12/25/travel/carry-on-netflix-movie-thriller.html',
#    'uri': 'nyt://article/489fdf9d-4448-5df5-8871-7bd1a08f29d5',
#    'byline': 'By Christine Chung',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T05:01:28-05:00',
#    'created_date': '2024-12-25T05:01:28-05:00',
#    'published_date': '2024-12-25T05:01:28-05:00',
#    'material_type_facet': '',
#    'kicker': 'Q. and A.',
#    'des_facet': ['Airport Security',
#     'Terrorism',
#     'Airlines and Airplanes',
#     'Writing and Writers',
#     'Christmas',
#     'Movies',
#     'Airports',
#     'Carry-On (Movie)'],
#    'org_facet': ['Transportation Security Administration'],
#    'per_facet': ['Egerton, Taron (1989- )', 'Bateman, Jason', 'T.J. Fixman'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25CarryOn-01-kcmq/25CarryOn-01-kcmq-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The actor Taron Egerton plays a T.S.A. agent who is extorted by a mysterious traveler into allowing a suspicious bag to get through airport security.',
#      'copyright': 'via Netflix'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25CarryOn-01-kcmq/25CarryOn-01-kcmq-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The actor Taron Egerton plays a T.S.A. agent who is extorted by a mysterious traveler into allowing a suspicious bag to get through airport security.',
#      'copyright': 'via Netflix'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25CarryOn-01-kcmq/25CarryOn-01-kcmq-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The actor Taron Egerton plays a T.S.A. agent who is extorted by a mysterious traveler into allowing a suspicious bag to get through airport security.',
#      'copyright': 'via Netflix'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Nosferatu’ Review: Drac’s Back, Sucking Blood and Souls',
#    'abstract': 'The director Robert Eggers dares you to feel seduced in his take on the classic vampire tale, starring Bill Skarsgard and Lily Rose Depp.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/nosferatu-review.html',
#    'uri': 'nyt://article/2b774a71-2e10-5445-85bb-7ed0e62e9470',
#    'byline': 'By Wesley Morris',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T09:50:48-05:00',
#    'created_date': '2024-12-25T05:01:00-05:00',
#    'published_date': '2024-12-25T05:01:00-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Vampires', 'Movies', 'Nosferatu (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Corrin, Emma (1995- )',
#     'Dafoe, Willem',
#     'Depp, Lily-Rose (1999- )',
#     'Eggers, Robert (Filmmaker)',
#     'Hoult, Nicholas',
#     'Skarsgard, Bill (1990- )'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25nosferatu-review-wjkz/25nosferatu-review-wjkz-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1107,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lily Rose Depp in “Nosferatu.” ',
#      'copyright': 'Focus Features'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25nosferatu-review-wjkz/25nosferatu-review-wjkz-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lily Rose Depp in “Nosferatu.” ',
#      'copyright': 'Focus Features'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25nosferatu-review-wjkz/25nosferatu-review-wjkz-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Lily Rose Depp in “Nosferatu.” ',
#      'copyright': 'Focus Features'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Vermiglio’ Review: Remote Rites of Passage',
#    'abstract': 'During World War II, life changes for a family in a Northern Italian mountain village when a Sicilian stranger arrives.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/vermiglio-review.html',
#    'uri': 'nyt://article/9da51471-dba6-5ab0-beee-50c674cf329b',
#    'byline': 'By Ben Kenigsberg',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T05:01:00-05:00',
#    'created_date': '2024-12-25T05:01:00-05:00',
#    'published_date': '2024-12-25T05:01:00-05:00',
#    'material_type_facet': '',
#    'kicker': 'Critic’s Pick',
#    'des_facet': ['Movies', 'Vermiglio (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Delpero, Maura'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25vermiglio-review-kbjf/25vermiglio-review-kbjf-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1080,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Pietro (Giuseppe De Domenico), left, a Sicilian, catches the eye of Lucia (Martina Scrinzi), a Northerner, in the Italian film “Vermiglio.”',
#      'copyright': 'Janus Films'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25vermiglio-review-kbjf/25vermiglio-review-kbjf-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Pietro (Giuseppe De Domenico), left, a Sicilian, catches the eye of Lucia (Martina Scrinzi), a Northerner, in the Italian film “Vermiglio.”',
#      'copyright': 'Janus Films'},
#     {'url': 'https://static01.nyt.com/images/2024/12/26/multimedia/25vermiglio-review-kbjf/25vermiglio-review-kbjf-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Pietro (Giuseppe De Domenico), left, a Sicilian, catches the eye of Lucia (Martina Scrinzi), a Northerner, in the Italian film “Vermiglio.”',
#      'copyright': 'Janus Films'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Better Man’ Review: The Boy in the Band',
#    'abstract': 'The singer Robbie Williams’s caustic, often vulnerable narration is the melody that enriches this musical biopic’s otherwise familiar beats of pop stardom.',
#    'url': 'https://www.nytimes.com/2024/12/25/movies/better-man-review.html',
#    'uri': 'nyt://article/a25fb353-3d0b-5023-b936-115426bfea27',
#    'byline': 'By Jeannette Catsoulis',
#    'item_type': 'Article',
#    'updated_date': '2024-12-25T05:00:55-05:00',
#    'created_date': '2024-12-25T05:00:55-05:00',
#    'published_date': '2024-12-25T05:00:55-05:00',
#    'material_type_facet': '',
#    'kicker': 'Critic’s pick',
#    'des_facet': ['Movies', 'Pop and Rock Music', 'Better Man (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Williams, Robbie', 'Gracey, Michael'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25betterman-review-qlhv/25betterman-review-qlhv-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 858,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jonno Davies as Robbie Williams, left, in “Better Man.”',
#      'copyright': 'Paramount Pictures'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/25betterman-review-qlhv/25betterman-review-qlhv-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 399,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Jonno Davies as Robbie Williams, left, in “Better Man.”',
#      'copyright': 'Paramount Pictures'},
# ...
#    'published_date': '2024-12-24T05:00:40-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Rap and Hip-Hop', 'Two Thousand Twenty Four'],
#    'org_facet': [],
#    'per_facet': ['Cobain, Cash',
#     'Combs, Sean',
#     'Common (Rapper)',
#     'Drake (Rapper)',
#     'Eminem',
#     'Future (Rapper)',
#     'GloRilla (Rapper)',
#     'Gunna (Rapper)',
#     'Lamar, Kendrick',
#     'NLE Choppa (Rapper)',
#     'YoungBoy Never Broke Again (Rapper)',
#     'Williams, Jeffery Lamar (Young Thug)',
#     'Wayne, Leland Tyler (Metro Boomin)',
#     'Tyler, the Creator',
#     'Snoop Dogg',
#     'Shaboozey (Singer)',
#     'SahBabii (Rapper)',
#     'Playboi Carti (Rapper)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/09/multimedia/24rap-convo-top/24rap-convo-top-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The blurry sound of the producer and rapper Cash Cobain help define the summer of 2024.',
#      'copyright': 'Andre D. Wagner for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/09/multimedia/24rap-convo-top/24rap-convo-top-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The blurry sound of the producer and rapper Cash Cobain help define the summer of 2024.',
#      'copyright': 'Andre D. Wagner for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/09/multimedia/24rap-convo-top/24rap-convo-top-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The blurry sound of the producer and rapper Cash Cobain help define the summer of 2024.',
#      'copyright': 'Andre D. Wagner for The New York Times'}],
#    'short_url': ''},
#   {'section': 'movies',
#    'subsection': '',
#    'title': '‘Rust’ Prosecutor Withdraws Appeal of Alec Baldwin Case',
#    'abstract': 'The decision ends the criminal prosecution of the actor for the fatal shooting on a film set. During his trial, the judge dismissed the involuntary manslaughter charge against him.',
#    'url': 'https://www.nytimes.com/2024/12/23/movies/rust-appeal-alec-baldwin-trial.html',
#    'uri': 'nyt://article/98d77538-6b9f-5d71-9bed-51a6f06d4ef0',
#    'byline': 'By Julia Jacobs',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T18:57:24-05:00',
#    'created_date': '2024-12-23T20:25:14-05:00',
#    'published_date': '2024-12-23T20:25:14-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Murders, Attempted Murders and Homicides',
#     'Prosecutorial Misconduct',
#     'Rust (Movie)'],
#    'org_facet': [],
#    'per_facet': ['Baldwin, Alec'],
#    'geo_facet': ['New Mexico'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/23rust-appeal-mwvz/23rust-appeal-mwvz-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The prosecutor in Alec Baldwin’s criminal case said she was abandoning her appeal because she did not have the full backing of the New Mexico attorney general’s office.',
#      'copyright': 'Julia Demaree Nikhinson/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/23rust-appeal-mwvz/23rust-appeal-mwvz-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The prosecutor in Alec Baldwin’s criminal case said she was abandoning her appeal because she did not have the full backing of the New Mexico attorney general’s office.',
#      'copyright': 'Julia Demaree Nikhinson/Associated Press'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/multimedia/23rust-appeal-mwvz/23rust-appeal-mwvz-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The prosecutor in Alec Baldwin’s criminal case said she was abandoning her appeal because she did not have the full backing of the New Mexico attorney general’s office.',
#      'copyright': 'Julia Demaree Nikhinson/Associated Press'}],
#    'short_url': ''},
#   {'section': 'nyregion',
#    'subsection': '',
#    'title': 'Steven Englander, Leader of an Outsider Art Outpost, Dies at 63',
#    'abstract': 'As director of the fiercely independent cultural center ABC No Rio, he led the battle to halt its eviction and later raised money to build a new home for the organization.',
#    'url': 'https://www.nytimes.com/2024/12/23/nyregion/steven-englander-dead.html',
#    'uri': 'nyt://article/743383c5-8d90-5117-b219-1380adae8f57',
#    'byline': 'By Colin Moynihan',
#    'item_type': 'Article',
#    'updated_date': '2024-12-23T16:32:29-05:00',
#    'created_date': '2024-12-23T16:32:29-05:00',
#    'published_date': '2024-12-23T16:32:29-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Deaths (Obituaries)', 'Art', 'Squatters', 'Gentrification'],
#    'org_facet': ['ABC No Rio'],
#    'per_facet': ['Englander, Steven (1961-2024)'],
#    'geo_facet': ['Lower East Side (Manhattan, NY)'],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20ENGLANDER-05-vlgj/20ENGLANDER-05-vlgj-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1367,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Steven Englander in 2016. He helped lead the Lower East Side cultural center ABC No Rio for more than 25 years, waging a contentious battle with the city over real estate. ',
#      'copyright': 'Karsten Moran for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20ENGLANDER-05-vlgj/20ENGLANDER-05-vlgj-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Steven Englander in 2016. He helped lead the Lower East Side cultural center ABC No Rio for more than 25 years, waging a contentious battle with the city over real estate. ',
#      'copyright': 'Karsten Moran for The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/20/multimedia/20ENGLANDER-05-vlgj/20ENGLANDER-05-vlgj-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Steven Englander in 2016. He helped lead the Lower East Side cultural center ABC No Rio for more than 25 years, waging a contentious battle with the city over real estate. ',
#      'copyright': 'Karsten Moran for The New York Times'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': '',
#    'title': 'Yoshio Taniguchi, Architect for MoMA’s Expansion, Dies at 87',
#    'abstract': 'He was a surprise choice for the ambitious project, but his design won praise as “drop-dead elegant.”',
#    'url': 'https://www.nytimes.com/2024/12/23/arts/yoshio-taniguchi-dead.html',
#    'uri': 'nyt://article/238a0c81-6677-58d8-8318-6a03d1342885',
#    'byline': 'By Fred A. Bernstein',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T11:32:59-05:00',
#    'created_date': '2024-12-23T14:57:36-05:00',
#    'published_date': '2024-12-23T14:57:36-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Deaths (Obituaries)',
#     'Architecture',
#     'Museums',
#     'Restoration and Renovation'],
#    'org_facet': ['Museum of Modern Art'],
#    'per_facet': ['Taniguchi, Yoshio'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/23Taniguchi-Subb2-jbpw-print2/23Taniguchi-Subb2-jbpw-print2-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 1946,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The entry to the newly expanded Museum of Modern Art in 2004. The Japanese architect Yoshio Taniguchi was a surprise choice to design the project.',
#      'copyright': 'Fred R. Conrad/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/23Taniguchi-Subb2-jbpw-print2/23Taniguchi-Subb2-jbpw-print2-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The entry to the newly expanded Museum of Modern Art in 2004. The Japanese architect Yoshio Taniguchi was a surprise choice to design the project.',
#      'copyright': 'Fred R. Conrad/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/24/multimedia/23Taniguchi-Subb2-jbpw-print2/23Taniguchi-Subb2-jbpw-print2-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'The entry to the newly expanded Museum of Modern Art in 2004. The Japanese architect Yoshio Taniguchi was a surprise choice to design the project.',
#      'copyright': 'Fred R. Conrad/The New York Times'}],
#    'short_url': ''},
#   {'section': 'arts',
#    'subsection': 'music',
#    'title': 'Alfa Anderson, Singer With Chic, Dies at 78',
#    'abstract': 'She sang the famous refrain “Le freak, c’est chic” on one of the biggest hits of the disco era and was a sought-after vocalist for many prominent artists.',
#    'url': 'https://www.nytimes.com/2024/12/23/arts/music/alfa-anderson-dead.html',
#    'uri': 'nyt://article/490b571d-e580-50aa-a7a5-2597b461f108',
#    'byline': 'By Amanda Holpuch',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T18:31:30-05:00',
#    'created_date': '2024-12-23T10:00:08-05:00',
#    'published_date': '2024-12-23T10:00:08-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Pop and Rock Music',
#     'Nineteen Hundred Eighties',
#     'Deaths (Obituaries)',
#     'Good Times (Song)',
#     'Le Freak (Song)'],
#    'org_facet': ['Chic (Music Group)'],
#    'per_facet': ['Anderson, Alfa (1946-2024)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/25/arts/23xp-anderson4-print3/23xp-anderson4-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Alfa Anderson performing with Luther Vandross in Chicago in 1987. She sang background vocals on Chic’s debut album before becoming one of the band’s lead vocalists, with Luci Martin, in 1978.',
#      'copyright': 'Raymond Boyd/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/arts/23xp-anderson4-print3/23xp-anderson4-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Alfa Anderson performing with Luther Vandross in Chicago in 1987. She sang background vocals on Chic’s debut album before becoming one of the band’s lead vocalists, with Luci Martin, in 1978.',
#      'copyright': 'Raymond Boyd/Getty Images'},
#     {'url': 'https://static01.nyt.com/images/2024/12/25/arts/23xp-anderson4-print3/23xp-anderson4-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Alfa Anderson performing with Luther Vandross in Chicago in 1987. She sang background vocals on Chic’s debut album before becoming one of the band’s lead vocalists, with Luci Martin, in 1978.',
#      'copyright': 'Raymond Boyd/Getty Images'}],
#    'short_url': ''},
#   {'section': 'books',
#    'subsection': 'review',
#    'title': 'Can You Find the 10 Hidden 2024 Best Sellers in This Text Puzzle?',
#    'abstract': 'This year saw a variety of novels on the New York Times best-sellers list, including the 10 titles lurking in this very short story.',
#    'url': 'https://www.nytimes.com/interactive/2024/12/23/books/review/2024-books-quiz.html',
#    'uri': 'nyt://interactive/18fc32b1-31a7-58eb-83f7-f0f3aa1d6a05',
#    'byline': 'By J. D. Biersdorfer',
#    'item_type': 'Interactive',
#    'updated_date': '2024-12-23T15:14:49-05:00',
#    'created_date': '2024-12-23T10:00:06-05:00',
#    'published_date': '2024-12-23T10:00:06-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Books and Literature'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/23/books/review/00BKS-QUIZ-bestsellers/00BKS-QUIZ-bestsellers-superJumbo.png',
#      'format': 'Super Jumbo',
#      'height': 1365,
#      'width': 2048,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Ben Hickey'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/books/review/00BKS-QUIZ-bestsellers/00BKS-QUIZ-bestsellers-threeByTwoSmallAt2X.png',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Ben Hickey'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/books/review/00BKS-QUIZ-bestsellers/00BKS-QUIZ-bestsellers-thumbLarge.png',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Ben Hickey'}],
#    'short_url': ''},
#   {'section': 'style',
#    'subsection': '',
#    'title': 'The Typography Maestro Getting Calls From Greta Gerwig and Robert Eggers',
#    'abstract': 'Teddy Blanks, the designer behind the memorable movie titles for films like “Nosferatu” and “Barbie,” has quietly become Hollywood’s go-to guy.',
#    'url': 'https://www.nytimes.com/2024/12/23/style/teddy-blanks-typeface-design-wicked-barbie-nosferatu.html',
#    'uri': 'nyt://article/9d19f402-f056-5e3d-add0-f8aa3b30c549',
#    'byline': 'By Alex Vadukul',
#    'item_type': 'Article',
#    'updated_date': '2024-12-24T18:17:04-05:00',
#    'created_date': '2024-12-23T05:03:10-05:00',
#    'published_date': '2024-12-23T05:03:10-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Content Type: Personal Profile', 'Typography', 'Movies'],
#    'org_facet': ['A24 Films LLC'],
#    'per_facet': ['Teddy Blanks',
#     'Gerwig, Greta',
#     'Bass, Saul',
#     'Eggers, Robert (Filmmaker)'],
#    'geo_facet': [],
#    'multimedia': [{'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23TEDDY-BLANKS-01-bhcm/23TEDDY-BLANKS-01-bhcm-superJumbo.jpg',
#      'format': 'Super Jumbo',
#      'height': 2048,
#      'width': 1366,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m often not paying attention to my surroundings,” said Teddy Blanks, here with his design studio’s resident dog, Omar. “I’m paying attention to the letters on signs around me.”',
#      'copyright': 'Graham Dickie/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23TEDDY-BLANKS-01-bhcm/23TEDDY-BLANKS-01-bhcm-threeByTwoSmallAt2X.jpg',
#      'format': 'threeByTwoSmallAt2X',
#      'height': 400,
#      'width': 600,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m often not paying attention to my surroundings,” said Teddy Blanks, here with his design studio’s resident dog, Omar. “I’m paying attention to the letters on signs around me.”',
#      'copyright': 'Graham Dickie/The New York Times'},
#     {'url': 'https://static01.nyt.com/images/2024/12/23/multimedia/23TEDDY-BLANKS-01-bhcm/23TEDDY-BLANKS-01-bhcm-thumbLarge.jpg',
#      'format': 'Large Thumbnail',
#      'height': 150,
#      'width': 150,
#      'type': 'image',
#      'subtype': 'photo',
#      'caption': '“I’m often not paying attention to my surroundings,” said Teddy Blanks, here with his design studio’s resident dog, Omar. “I’m paying attention to the letters on signs around me.”',
#      'copyright': 'Graham Dickie/The New York Times'}],
#    'short_url': ''}]}
